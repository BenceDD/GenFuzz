# %%
import os
import json

def json_fuzzer():     #json_to_fuzz):
    #do something
    #fuzzed_json = json_to_fuzz
    parsing = "./json_for_fuzzing/test_parsing/"
    transform = "./json_for_fuzzing/test_transform/"
    jsons = []
    
    for json_filename in os.listdir(parsing):
        jsons.append(parsing+json_filename)
        
    for json_filename in os.listdir(transform):
        jsons.append(transform+json_filename)
        
    #return fuzzed_json

    json_pieces = []
    
    for json_filename in jsons:
        with open(json_filename) as file:
            #json_pieces.append(json.load(file))
            try:
                print(file.name)
                print(json.load(file))
            except Exception as e:
                #print('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
                print(e)

        
        
json_fuzzer()
# Out:
# ./json_for_fuzzing/test_parsing/i_number_double_huge_neg_exp.json
# [0.0]
# ./json_for_fuzzing/test_parsing/i_number_huge_exp.json
# [inf]
# ./json_for_fuzzing/test_parsing/i_number_neg_int_huge_exp.json
# [-inf]
# ./json_for_fuzzing/test_parsing/i_number_pos_double_huge_exp.json
# [inf]
# ./json_for_fuzzing/test_parsing/i_number_real_neg_overflow.json
# [-inf]
# ./json_for_fuzzing/test_parsing/i_number_real_pos_overflow.json
# [inf]
# ./json_for_fuzzing/test_parsing/i_number_real_underflow.json
# [0.0]
# ./json_for_fuzzing/test_parsing/i_number_too_big_neg_int.json
# [-123123123123123123123123123123]
# ./json_for_fuzzing/test_parsing/i_number_too_big_pos_int.json
# [100000000000000000000]
# ./json_for_fuzzing/test_parsing/i_number_very_big_negative_int.json
# [-237462374673276894279832749832423479823246327846]
# ./json_for_fuzzing/test_parsing/i_object_key_lone_2nd_surrogate.json
# {'\udfaa': 0}
# ./json_for_fuzzing/test_parsing/i_string_1st_surrogate_but_2nd_missing.json
# ['\udada']
# ./json_for_fuzzing/test_parsing/i_string_1st_valid_surrogate_2nd_invalid.json
# ['\ud888ሴ']
# ./json_for_fuzzing/test_parsing/i_string_incomplete_surrogates_escape_valid.json
# ['\ud800\ud800\n']
# ./json_for_fuzzing/test_parsing/i_string_incomplete_surrogate_and_escape_valid.json
# ['\ud800\n']
# ./json_for_fuzzing/test_parsing/i_string_incomplete_surrogate_pair.json
# ['\udd1ea']
# ./json_for_fuzzing/test_parsing/i_string_invalid_lonely_surrogate.json
# ['\ud800']
# ./json_for_fuzzing/test_parsing/i_string_invalid_surrogate.json
# ['\ud800abc']
# ./json_for_fuzzing/test_parsing/i_string_invalid_utf-8.json
# ['˙']
# ./json_for_fuzzing/test_parsing/i_string_inverted_surrogates_U+1D11E.json
# ['\udd1e\ud834']
# ./json_for_fuzzing/test_parsing/i_string_iso_latin_1.json
# ['é']
# ./json_for_fuzzing/test_parsing/i_string_lone_second_surrogate.json
# ['\udfaa']
# ./json_for_fuzzing/test_parsing/i_string_lone_utf8_continuation_byte.json
# 'charmap' codec can't decode byte 0x81 in position 2: character maps to <undefined>
# ./json_for_fuzzing/test_parsing/i_string_not_in_unicode_range.json
# ['ôżżż']
# ./json_for_fuzzing/test_parsing/i_string_overlong_sequence_2_bytes.json
# ['ŔŻ']
# ./json_for_fuzzing/test_parsing/i_string_overlong_sequence_6_bytes.json
# 'charmap' codec can't decode byte 0x83 in position 3: character maps to <undefined>
# ./json_for_fuzzing/test_parsing/i_string_overlong_sequence_6_bytes_null.json
# ['ü€€€€€']
# ./json_for_fuzzing/test_parsing/i_string_truncated-utf-8.json
# ['ŕ˙']
# ./json_for_fuzzing/test_parsing/i_string_UTF-16LE_with_BOM.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/i_string_UTF-8_invalid_sequence.json
# 'charmap' codec can't decode byte 0x88 in position 6: character maps to <undefined>
# ./json_for_fuzzing/test_parsing/i_string_utf16BE_no_BOM.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/i_string_utf16LE_no_BOM.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/i_string_UTF8_surrogate_U+D800.json
# ['í\xa0€']
# ./json_for_fuzzing/test_parsing/i_structure_500_nested_arrays.json
# [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
# ./json_for_fuzzing/test_parsing/i_structure_UTF-8_BOM_empty_object.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_array_1_true_without_comma.json
# Expecting ',' delimiter: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_array_a_invalid_utf8.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_array_colon_instead_of_comma.json
# Expecting ',' delimiter: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_array_comma_after_close.json
# Extra data: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_array_comma_and_number.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_array_double_comma.json
# Expecting value: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_array_double_extra_comma.json
# Expecting value: line 1 column 6 (char 5)
# ./json_for_fuzzing/test_parsing/n_array_extra_close.json
# Extra data: line 1 column 6 (char 5)
# ./json_for_fuzzing/test_parsing/n_array_extra_comma.json
# Expecting value: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_array_incomplete.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_array_incomplete_invalid_value.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_array_inner_array_no_comma.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_array_invalid_utf8.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_array_items_separated_by_semicolon.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_array_just_comma.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_array_just_minus.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_array_missing_value.json
# Expecting value: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_array_newlines_unclosed.json
# Expecting value: line 3 column 4 (char 11)
# ./json_for_fuzzing/test_parsing/n_array_number_and_comma.json
# Expecting value: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_array_number_and_several_commas.json
# Expecting value: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_array_spaces_vertical_tab_formfeed.json
# Invalid control character at: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_array_star_inside.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_array_unclosed.json
# Expecting ',' delimiter: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_array_unclosed_trailing_comma.json
# Expecting value: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_array_unclosed_with_new_lines.json
# Expecting ',' delimiter: line 3 column 3 (char 8)
# ./json_for_fuzzing/test_parsing/n_array_unclosed_with_object_inside.json
# Expecting ',' delimiter: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_incomplete_false.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_incomplete_null.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_incomplete_true.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_multidigit_number_then_00.json
# Extra data: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_number_++.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_+1.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_+Inf.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_-01.json
# Expecting ',' delimiter: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_number_-1.0..json
# Expecting ',' delimiter: line 1 column 6 (char 5)
# ./json_for_fuzzing/test_parsing/n_number_-2..json
# Expecting ',' delimiter: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_number_-NaN.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_.-1.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_.2e-3.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_0.1.2.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_number_0.3e+.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_number_0.3e.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_number_0.e1.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_0e+.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_0e.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_0_capital_E+.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_0_capital_E.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_1.0e+.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_number_1.0e-.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_number_1.0e.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_number_1eE2.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_1_000.json
# Expecting ',' delimiter: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_number_2.e+3.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_2.e-3.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_2.e3.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_9.e+.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_expression.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_hex_1_digit.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_hex_2_digits.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_Inf.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_infinity.json
# [inf]
# ./json_for_fuzzing/test_parsing/n_number_invalid+-.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_invalid-negative-real.json
# Expecting ',' delimiter: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_number_invalid-utf-8-in-bigger-int.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_number_invalid-utf-8-in-exponent.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_number_invalid-utf-8-in-int.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_minus_infinity.json
# [-inf]
# ./json_for_fuzzing/test_parsing/n_number_minus_sign_with_trailing_garbage.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_minus_space_1.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_NaN.json
# [nan]
# ./json_for_fuzzing/test_parsing/n_number_neg_int_starting_with_zero.json
# Expecting ',' delimiter: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_number_neg_real_without_int_part.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_neg_with_garbage_at_end.json
# Expecting ',' delimiter: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_number_real_garbage_after_e.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_real_without_fractional_part.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_real_with_invalid_utf8_after_e.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_number_starting_with_dot.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_U+FF11_fullwidth_digit_one.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_number_with_alpha.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_number_with_alpha_char.json
# Expecting ',' delimiter: line 1 column 20 (char 19)
# ./json_for_fuzzing/test_parsing/n_number_with_leading_zero.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_object_bad_value.json
# Expecting value: line 1 column 7 (char 6)
# ./json_for_fuzzing/test_parsing/n_object_bracket_key.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_object_comma_instead_of_colon.json
# Expecting ':' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_object_double_colon.json
# Expecting value: line 1 column 6 (char 5)
# ./json_for_fuzzing/test_parsing/n_object_emoji.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_object_garbage_at_end.json
# Expecting ',' delimiter: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_object_key_with_single_quotes.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_object_lone_continuation_byte_in_key_and_trailing_comma.json
# Expecting property name enclosed in double quotes: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_object_missing_colon.json
# Expecting ':' delimiter: line 1 column 6 (char 5)
# ./json_for_fuzzing/test_parsing/n_object_missing_key.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_object_missing_semicolon.json
# Expecting ':' delimiter: line 1 column 6 (char 5)
# ./json_for_fuzzing/test_parsing/n_object_missing_value.json
# Expecting value: line 1 column 6 (char 5)
# ./json_for_fuzzing/test_parsing/n_object_no-colon.json
# Expecting ':' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_object_non_string_key.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_object_non_string_key_but_huge_number_instead.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_object_repeated_null_null.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_object_several_trailing_commas.json
# Expecting property name enclosed in double quotes: line 1 column 9 (char 8)
# ./json_for_fuzzing/test_parsing/n_object_single_quote.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_object_trailing_comma.json
# Expecting property name enclosed in double quotes: line 1 column 9 (char 8)
# ./json_for_fuzzing/test_parsing/n_object_trailing_comment.json
# Extra data: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_object_trailing_comment_open.json
# Extra data: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_object_trailing_comment_slash_open.json
# Extra data: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_object_trailing_comment_slash_open_incomplete.json
# Extra data: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_object_two_commas_in_a_row.json
# Expecting property name enclosed in double quotes: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_object_unquoted_key.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_object_unterminated-value.json
# Unterminated string starting at: line 1 column 6 (char 5)
# ./json_for_fuzzing/test_parsing/n_object_with_single_string.json
# Expecting ':' delimiter: line 1 column 22 (char 21)
# ./json_for_fuzzing/test_parsing/n_object_with_trailing_garbage.json
# Extra data: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_single_space.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_string_1_surrogate_then_escape.json
# Unterminated string starting at: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_string_1_surrogate_then_escape_u.json
# Invalid \uXXXX escape: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_string_1_surrogate_then_escape_u1.json
# Invalid \uXXXX escape: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_string_1_surrogate_then_escape_u1x.json
# Invalid \uXXXX escape: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_string_accentuated_char_no_quotes.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_string_backslash_00.json
# Invalid \escape: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_string_escaped_backslash_bad.json
# Unterminated string starting at: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_string_escaped_ctrl_char_tab.json
# Invalid \escape: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_string_escaped_emoji.json
# Invalid \escape: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_string_escape_x.json
# Invalid \escape: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_string_incomplete_escape.json
# Unterminated string starting at: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_string_incomplete_escaped_character.json
# Invalid \uXXXX escape: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_string_incomplete_surrogate.json
# Invalid \uXXXX escape: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_string_incomplete_surrogate_escape_invalid.json
# Invalid \escape: line 1 column 15 (char 14)
# ./json_for_fuzzing/test_parsing/n_string_invalid-utf-8-in-escape.json
# Invalid \uXXXX escape: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_string_invalid_backslash_esc.json
# Invalid \escape: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_string_invalid_unicode_escape.json
# Invalid \uXXXX escape: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_string_invalid_utf8_after_escape.json
# Invalid \escape: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_string_leading_uescaped_thinspace.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_string_no_quotes_with_bad_escape.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_string_single_doublequote.json
# Unterminated string starting at: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_string_single_quote.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_string_single_string_no_double_quotes.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_string_start_escape_unclosed.json
# Unterminated string starting at: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_string_unescaped_crtl_char.json
# Invalid control character at: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_string_unescaped_newline.json
# Invalid control character at: line 1 column 6 (char 5)
# ./json_for_fuzzing/test_parsing/n_string_unescaped_tab.json
# Invalid control character at: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_string_unicode_CapitalU.json
# Invalid \escape: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_string_with_trailing_garbage.json
# Extra data: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_structure_100000_opening_arrays.json
# maximum recursion depth exceeded while decoding a JSON array from a unicode string
# ./json_for_fuzzing/test_parsing/n_structure_angle_bracket_..json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_structure_angle_bracket_null.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_array_trailing_garbage.json
# Extra data: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_structure_array_with_extra_array_close.json
# Extra data: line 1 column 4 (char 3)
# ./json_for_fuzzing/test_parsing/n_structure_array_with_unclosed_string.json
# Unterminated string starting at: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_ascii-unicode-identifier.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_structure_capitalized_True.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_close_unopened_array.json
# Extra data: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_comma_instead_of_closing_brace.json
# Expecting property name enclosed in double quotes: line 1 column 12 (char 11)
# ./json_for_fuzzing/test_parsing/n_structure_double_array.json
# Extra data: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_structure_end_array.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_structure_incomplete_UTF8_BOM.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_structure_lone-invalid-utf-8.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_structure_lone-open-bracket.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_no_data.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_structure_null-byte-outside-string.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_number_with_trailing_garbage.json
# Extra data: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_object_followed_by_closing_object.json
# Extra data: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_structure_object_unclosed_no_value.json
# Expecting value: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_structure_object_with_comment.json
# Expecting value: line 1 column 6 (char 5)
# ./json_for_fuzzing/test_parsing/n_structure_object_with_trailing_garbage.json
# Extra data: line 1 column 13 (char 12)
# ./json_for_fuzzing/test_parsing/n_structure_open_array_apostrophe.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_open_array_comma.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_open_array_object.json
# maximum recursion depth exceeded while decoding a JSON object from a unicode string
# ./json_for_fuzzing/test_parsing/n_structure_open_array_open_object.json
# Expecting property name enclosed in double quotes: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_structure_open_array_open_string.json
# Unterminated string starting at: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_open_array_string.json
# Expecting ',' delimiter: line 1 column 5 (char 4)
# ./json_for_fuzzing/test_parsing/n_structure_open_object.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_open_object_close_array.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_open_object_comma.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_open_object_open_array.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_open_object_open_string.json
# Unterminated string starting at: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_open_object_string_with_apostrophes.json
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_open_open.json
# Invalid \escape: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_structure_single_eacute.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_structure_single_star.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_structure_trailing_#.json
# Extra data: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_structure_U+2060_word_joined.json
# 'charmap' codec can't decode byte 0x81 in position 2: character maps to <undefined>
# ./json_for_fuzzing/test_parsing/n_structure_uescaped_LF_before_string.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_unclosed_array.json
# Expecting ',' delimiter: line 1 column 3 (char 2)
# ./json_for_fuzzing/test_parsing/n_structure_unclosed_array_partial_null.json
# Expecting value: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_structure_unclosed_array_unfinished_false.json
# Expecting value: line 1 column 9 (char 8)
# ./json_for_fuzzing/test_parsing/n_structure_unclosed_array_unfinished_true.json
# Expecting value: line 1 column 10 (char 9)
# ./json_for_fuzzing/test_parsing/n_structure_unclosed_object.json
# Expecting ',' delimiter: line 1 column 13 (char 12)
# ./json_for_fuzzing/test_parsing/n_structure_unicode-identifier.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_structure_UTF8_BOM_no_data.json
# Expecting value: line 1 column 1 (char 0)
# ./json_for_fuzzing/test_parsing/n_structure_whitespace_formfeed.json
# Expecting value: line 1 column 2 (char 1)
# ./json_for_fuzzing/test_parsing/n_structure_whitespace_U+2060_word_joiner.json
# 'charmap' codec can't decode byte 0x81 in position 2: character maps to <undefined>
# ./json_for_fuzzing/test_parsing/y_array_arraysWithSpaces.json
# [[]]
# ./json_for_fuzzing/test_parsing/y_array_empty-string.json
# ['']
# ./json_for_fuzzing/test_parsing/y_array_empty.json
# []
# ./json_for_fuzzing/test_parsing/y_array_ending_with_newline.json
# ['a']
# ./json_for_fuzzing/test_parsing/y_array_false.json
# [False]
# ./json_for_fuzzing/test_parsing/y_array_heterogeneous.json
# [None, 1, '1', {}]
# ./json_for_fuzzing/test_parsing/y_array_null.json
# [None]
# ./json_for_fuzzing/test_parsing/y_array_with_1_and_newline.json
# [1]
# ./json_for_fuzzing/test_parsing/y_array_with_leading_space.json
# [1]
# ./json_for_fuzzing/test_parsing/y_array_with_several_null.json
# [1, None, None, None, 2]
# ./json_for_fuzzing/test_parsing/y_array_with_trailing_space.json
# [2]
# ./json_for_fuzzing/test_parsing/y_number.json
# [1.23e+67]
# ./json_for_fuzzing/test_parsing/y_number_0e+1.json
# [0.0]
# ./json_for_fuzzing/test_parsing/y_number_0e1.json
# [0.0]
# ./json_for_fuzzing/test_parsing/y_number_after_space.json
# [4]
# ./json_for_fuzzing/test_parsing/y_number_double_close_to_zero.json
# [-1e-78]
# ./json_for_fuzzing/test_parsing/y_number_int_with_exp.json
# [200.0]
# ./json_for_fuzzing/test_parsing/y_number_minus_zero.json
# [0]
# ./json_for_fuzzing/test_parsing/y_number_negative_int.json
# [-123]
# ./json_for_fuzzing/test_parsing/y_number_negative_one.json
# [-1]
# ./json_for_fuzzing/test_parsing/y_number_negative_zero.json
# [0]
# ./json_for_fuzzing/test_parsing/y_number_real_capital_e.json
# [1e+22]
# ./json_for_fuzzing/test_parsing/y_number_real_capital_e_neg_exp.json
# [0.01]
# ./json_for_fuzzing/test_parsing/y_number_real_capital_e_pos_exp.json
# [100.0]
# ./json_for_fuzzing/test_parsing/y_number_real_exponent.json
# [1.23e+47]
# ./json_for_fuzzing/test_parsing/y_number_real_fraction_exponent.json
# [1.23456e+80]
# ./json_for_fuzzing/test_parsing/y_number_real_neg_exp.json
# [0.01]
# ./json_for_fuzzing/test_parsing/y_number_real_pos_exponent.json
# [100.0]
# ./json_for_fuzzing/test_parsing/y_number_simple_int.json
# [123]
# ./json_for_fuzzing/test_parsing/y_number_simple_real.json
# [123.456789]
# ./json_for_fuzzing/test_parsing/y_object.json
# {'asd': 'sdf', 'dfg': 'fgh'}
# ./json_for_fuzzing/test_parsing/y_object_basic.json
# {'asd': 'sdf'}
# ./json_for_fuzzing/test_parsing/y_object_duplicated_key.json
# {'a': 'c'}
# ./json_for_fuzzing/test_parsing/y_object_duplicated_key_and_value.json
# {'a': 'b'}
# ./json_for_fuzzing/test_parsing/y_object_empty.json
# {}
# ./json_for_fuzzing/test_parsing/y_object_empty_key.json
# {'': 0}
# ./json_for_fuzzing/test_parsing/y_object_escaped_null_in_key.json
# {'foo\x00bar': 42}
# ./json_for_fuzzing/test_parsing/y_object_extreme_numbers.json
# {'min': -1e+28, 'max': 1e+28}
# ./json_for_fuzzing/test_parsing/y_object_long_strings.json
# {'x': [{'id': 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'}], 'id': 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'}
# ./json_for_fuzzing/test_parsing/y_object_simple.json
# {'a': []}
# ./json_for_fuzzing/test_parsing/y_object_string_unicode.json
# {'title': 'Полтора Землекопа'}
# ./json_for_fuzzing/test_parsing/y_object_with_newlines.json
# {'a': 'b'}
# ./json_for_fuzzing/test_parsing/y_string_1_2_3_bytes_UTF-8_sequences.json
# ['`Īካ']
# ./json_for_fuzzing/test_parsing/y_string_accepted_surrogate_pair.json
# ['𐐷']
# ./json_for_fuzzing/test_parsing/y_string_accepted_surrogate_pairs.json
# ['😹💍']
# ./json_for_fuzzing/test_parsing/y_string_allowed_escapes.json
# ['"\\/\x08\x0c\n\r\t']
# ./json_for_fuzzing/test_parsing/y_string_backslash_and_u_escaped_zero.json
# ['\\u0000']
# ./json_for_fuzzing/test_parsing/y_string_backslash_doublequotes.json
# ['"']
# ./json_for_fuzzing/test_parsing/y_string_comments.json
# ['a/*b*/c/*d//e']
# ./json_for_fuzzing/test_parsing/y_string_double_escape_a.json
# ['\\a']
# ./json_for_fuzzing/test_parsing/y_string_double_escape_n.json
# ['\\n']
# ./json_for_fuzzing/test_parsing/y_string_escaped_control_character.json
# ['\x12']
# ./json_for_fuzzing/test_parsing/y_string_escaped_noncharacter.json
# ['\uffff']
# ./json_for_fuzzing/test_parsing/y_string_in_array.json
# ['asd']
# ./json_for_fuzzing/test_parsing/y_string_in_array_with_leading_space.json
# ['asd']
# ./json_for_fuzzing/test_parsing/y_string_last_surrogates_1_and_2.json
# ['\U0010ffff']
# ./json_for_fuzzing/test_parsing/y_string_nbsp_uescaped.json
# ['new\xa0line']
# ./json_for_fuzzing/test_parsing/y_string_nonCharacterInUTF-8_U+10FFFF.json
# ['ôŹżż']
# ./json_for_fuzzing/test_parsing/y_string_nonCharacterInUTF-8_U+FFFF.json
# ['ďżż']
# ./json_for_fuzzing/test_parsing/y_string_null_escape.json
# ['\x00']
# ./json_for_fuzzing/test_parsing/y_string_one-byte-utf-8.json
# [',']
# ./json_for_fuzzing/test_parsing/y_string_pi.json
# ['Ď€']
# ./json_for_fuzzing/test_parsing/y_string_reservedCharacterInUTF-8_U+1BFFF.json
# ['đ›żż']
# ./json_for_fuzzing/test_parsing/y_string_simple_ascii.json
# ['asd ']
# ./json_for_fuzzing/test_parsing/y_string_space.json
#
# ./json_for_fuzzing/test_parsing/y_string_surrogates_U+1D11E_MUSICAL_SYMBOL_G_CLEF.json
# ['𝄞']
# ./json_for_fuzzing/test_parsing/y_string_three-byte-utf-8.json
# ['ࠡ']
# ./json_for_fuzzing/test_parsing/y_string_two-byte-utf-8.json
# ['ģ']
# ./json_for_fuzzing/test_parsing/y_string_u+2028_line_sep.json
# ['â€¨']
# ./json_for_fuzzing/test_parsing/y_string_u+2029_par_sep.json
# ['â€©']
# ./json_for_fuzzing/test_parsing/y_string_uEscape.json
# ['aクリス']
# ./json_for_fuzzing/test_parsing/y_string_uescaped_newline.json
# ['new\nline']
# ./json_for_fuzzing/test_parsing/y_string_unescaped_char_delete.json
# ['\x7f']
# ./json_for_fuzzing/test_parsing/y_string_unicode.json
# ['ꙭ']
# ./json_for_fuzzing/test_parsing/y_string_unicodeEscapedBackslash.json
# ['\\']
# ./json_for_fuzzing/test_parsing/y_string_unicode_2.json
# 'charmap' codec can't decode byte 0x88 in position 6: character maps to <undefined>
# ./json_for_fuzzing/test_parsing/y_string_unicode_escaped_double_quote.json
# ['"']
# ./json_for_fuzzing/test_parsing/y_string_unicode_U+10FFFE_nonchar.json
# ['\U0010fffe']
# ./json_for_fuzzing/test_parsing/y_string_unicode_U+1FFFE_nonchar.json
# ['\U0001fffe']
# ./json_for_fuzzing/test_parsing/y_string_unicode_U+200B_ZERO_WIDTH_SPACE.json
# ['\u200b']
# ./json_for_fuzzing/test_parsing/y_string_unicode_U+2064_invisible_plus.json
# ['\u2064']
# ./json_for_fuzzing/test_parsing/y_string_unicode_U+FDD0_nonchar.json
# ['\ufdd0']
# ./json_for_fuzzing/test_parsing/y_string_unicode_U+FFFE_nonchar.json
# ['\ufffe']
# ./json_for_fuzzing/test_parsing/y_string_utf8.json
# ['â‚¬đť„ž']
# ./json_for_fuzzing/test_parsing/y_string_with_del_character.json
# ['a\x7fa']
# ./json_for_fuzzing/test_parsing/y_structure_lonely_false.json
# False
# ./json_for_fuzzing/test_parsing/y_structure_lonely_int.json
# 42
# ./json_for_fuzzing/test_parsing/y_structure_lonely_negative_real.json
# -0.1
# ./json_for_fuzzing/test_parsing/y_structure_lonely_null.json
# None
# ./json_for_fuzzing/test_parsing/y_structure_lonely_string.json
# asd
# ./json_for_fuzzing/test_parsing/y_structure_lonely_true.json
# True
# ./json_for_fuzzing/test_parsing/y_structure_string_empty.json
#
# ./json_for_fuzzing/test_parsing/y_structure_trailing_newline.json
# ['a']
# ./json_for_fuzzing/test_parsing/y_structure_true_in_array.json
# [True]
# ./json_for_fuzzing/test_parsing/y_structure_whitespace_array.json
# []
# ./json_for_fuzzing/test_transform/number_1.0.json
# [1.0]
# ./json_for_fuzzing/test_transform/number_1.000000000000000005.json
# [1.0]
# ./json_for_fuzzing/test_transform/number_1000000000000000.json
# [1000000000000000]
# ./json_for_fuzzing/test_transform/number_10000000000000000999.json
# [10000000000000000999]
# ./json_for_fuzzing/test_transform/number_1e-999.json
# [0.0]
# ./json_for_fuzzing/test_transform/number_1e6.json
# [1000000.0]
# ./json_for_fuzzing/test_transform/object_key_nfc_nfd.json
# 'charmap' codec can't decode byte 0x81 in position 15: character maps to <undefined>
# ./json_for_fuzzing/test_transform/object_key_nfd_nfc.json
# 'charmap' codec can't decode byte 0x81 in position 4: character maps to <undefined>
# ./json_for_fuzzing/test_transform/object_same_key_different_values.json
# {'a': 2}
# ./json_for_fuzzing/test_transform/object_same_key_same_value.json
# {'a': 1}
# ./json_for_fuzzing/test_transform/object_same_key_unclear_values.json
# {'a': 0}
# ./json_for_fuzzing/test_transform/string_1_escaped_invalid_codepoint.json
# ['\ud800']
# ./json_for_fuzzing/test_transform/string_1_invalid_codepoint.json
# ['í\xa0€']
# ./json_for_fuzzing/test_transform/string_2_escaped_invalid_codepoints.json
# ['\ud800\ud800']
# ./json_for_fuzzing/test_transform/string_2_invalid_codepoints.json
# ['í\xa0€í\xa0€']
# ./json_for_fuzzing/test_transform/string_3_escaped_invalid_codepoints.json
# ['\ud800\ud800\ud800']
# ./json_for_fuzzing/test_transform/string_3_invalid_codepoints.json
# ['í\xa0€í\xa0€í\xa0€']
# ./json_for_fuzzing/test_transform/string_with_escaped_NULL.json
# ['A\x00B']
